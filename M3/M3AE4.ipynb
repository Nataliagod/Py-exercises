# %% [markdown]
# ## Seaborn es una librería que contiene mucha utilidades. Una de ellas es un conjunto de dataset de ejemplos con los que tendremos datos para analizar y así no necesitaremos cargar archivos externos.

# %% [markdown]
# ### a) Averiguar cuáles son algunos de los dataset que contiene Seaborn

# %%
# importar a biblioteca seaborn
import seaborn as sns

# obtenemos los nombres de los datasets disponibles
datasets = sns.get_dataset_names()

# imprimimos los nombres de los datasets
for dataset in datasets:
    print(dataset)
# Out:
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# dowjones
# exercise
# flights
# fmri
# geyser
# glue
# healthexp
# iris
# mpg
# penguins
# planets
# seaice
# taxis
# tips
# titanic
# anagrams
# anagrams
# anscombe
# anscombe
# attention
# attention
# brain_networks
# brain_networks
# car_crashes
# car_crashes
# diamonds
# diamonds
# dots
# dots
# dowjones
# dowjones
# exercise
# exercise
# flights
# flights
# fmri
# fmri
# geyser
# geyser
# glue
# glue
# healthexp
# healthexp
# iris
# iris
# mpg
# mpg
# penguins
# penguins
# planets
# planets
# seaice
# seaice
# taxis
# taxis
# tips
# tips
# titanic
# titanic
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# dowjones
# exercise
# flights
# fmri
# geyser
# glue
# healthexp
# iris
# mpg
# penguins
# planets
# seaice
# taxis
# tips
# titanic

# %% [markdown]
# ### b) Cargar el dataset de titanic, se utilizará en los siguientes ejercicios.

# %%
# Importar seaborn
import seaborn as sns

# Cargar el dataset de Titanic
titanic_df = sns.load_dataset('titanic')

# Mostrar las primeras 5 filas del dataframe
print(titanic_df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### c) Confeccione un gráfico de barras para visualizar hombres y mujeres que han sobrevivido.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar el dataframe para obtener solo los datos de los sobrevivientes
sobrevivientes_df = titanic_df[titanic_df['survived'] == 1]

# Contar el número de sobrevivientes por género
sobrevivientes_por_genero = sobrevivientes_df['sex'].value_counts()

# Crear el gráfico de barras
sns.barplot(x=sobrevivientes_por_genero.index.map({'female': 'mujer', 'male': 'hombre'}),
            y=sobrevivientes_por_genero.values,
            hue_order=['mujer', 'hombre'])

# Añadir título y etiquetas
plt.title('Sobrevivientes por Género')
plt.xlabel('Género')
plt.ylabel('Número de Sobrevivientes')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Otra opcion de graficar considerando tambien los fallecidos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Agrupar los datos por género y estado de supervivencia, contando el número de personas
sobrevivientes_y_fallecidos_por_genero = titanic_df.groupby(['sex', 'survived']).size().unstack()

# Renombrar las etiquetas de género y estado de supervivencia
sobrevivientes_y_fallecidos_por_genero.index = ['hombre', 'mujer']
sobrevivientes_y_fallecidos_por_genero.columns = ['fallecido', 'sobreviviente']

# Crear el gráfico de barras
grafico = sobrevivientes_y_fallecidos_por_genero.plot(kind='bar', stacked=False)

# Añadir título y etiquetas
plt.title('Sobrevivientes y Fallecidos por Género')
plt.xlabel('Género')
plt.ylabel('Número de Personas')

# Cambiar la orientación de las etiquetas del eje x
grafico.set_xticklabels(grafico.get_xticklabels(), rotation=0)

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Agrupar los datos por género y estado de supervivencia, contando el número de personas
sobrevivientes_y_fallecidos_por_genero = titanic_df.groupby(['sex', 'survived']).size().unstack()

# Renombrar las etiquetas de género y estado de supervivencia
sobrevivientes_y_fallecidos_por_genero.index = ['hombre', 'mujer']
sobrevivientes_y_fallecidos_por_genero.columns = ['fallecido', 'sobreviviente']

# Crear el gráfico de barras
sobrevivientes_y_fallecidos_por_genero.plot(kind='bar', stacked=False)

# Añadir título y etiquetas
plt.title('Sobrevivientes y Fallecidos por Género')
plt.xlabel('Género')
plt.ylabel('Número de Personas')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### d) Crear un gráfico de distribución de edades por clase de pasajero

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el gráfico de distribución de edades por clase de pasajero
sns.histplot(data=titanic_df, x='age', hue='pclass', multiple='stack', kde=True)

# Añadir título y etiquetas en español
plt.title('Distribución de Edades por Clase de Pasajero')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Cambiar el texto de la leyenda a español
plt.legend(title='Clase', labels=['Primera Clase', 'Segunda Clase', 'Tercera Clase'])

# Mostrar el gráfico
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Otra forma de hacer el gráfico

# %%
# Importar matplotlib
import matplotlib.pyplot as plt

# Crear un histograma de 'age' para cada 'class'
for clase in df['class'].unique():
    plt.hist(df[df['class'] == clase]['age'].dropna(), bins=30, alpha=0.5, label=str(clase))

# Agregar títulos y etiquetas
plt.title('Distribución de edades por clase de pasajero')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend(title='Clase')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### e) Diagrama de Caja (Boxplot) de Tarifas por Puerto de Embarque.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el diagrama de caja de las tarifas por puerto de embarque
sns.boxplot(data=titanic_df, x='embarked', y='fare')

# Obtener los nombres de los puertos de embarque
puertos_de_embarque = ['Cherbourg', 'Queenstown', 'Southampton']

# Añadir los nombres de los puertos de embarque como etiquetas en el eje x
plt.xticks(ticks=[0, 1, 2], labels=puertos_de_embarque)

# Añadir título y etiquetas
plt.title('Diagrama de Caja de Tarifas por Puerto de Embarque')
plt.xlabel('Puerto de Embarque')
plt.ylabel('Tarifa')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Otra forma de hacer el gráfico

# %%
# Importar seaborn
import seaborn as sns

# Importar matplotlib
import matplotlib.pyplot as plt

# Crear un boxplot de 'fare' para cada 'embark_town'
sns.boxplot(x='embark_town', y='fare', data=df)

# Agregar títulos y etiquetas
plt.title('Tarifas por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Tarifa')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### f) Gráfico de Violín de Edades por Supervivencia.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el gráfico de violín de las edades por supervivencia
sns.violinplot(data=titanic_df, x='survived', y='age')

# Añadir título y etiquetas
plt.title('Gráfico de Violín de Edades por Supervivencia')
plt.xlabel('Sobrevivencia')
plt.ylabel('Edad')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### g) Diagrama de dispersión de Tarifas vs. Edades por Supervivencia.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el diagrama de dispersión de Tarifas vs. Edades por Supervivencia
sns.scatterplot(data=titanic_df, x='age', y='fare', hue='survived')

# Añadir título y etiquetas
plt.title('Diagrama de Dispersión de Tarifas vs. Edades por Supervivencia')
plt.xlabel('Edad')
plt.ylabel('Tarifa')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### h) Crear un gráficos de pilas agrupadas según supervivencia vs clase, agrupadas por puerto de embarque.

# %%
# Importar pandas y matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Crear un dataframe pivotado para el gráfico
pivot_df = df.pivot_table(values='survived', index=['embark_town', 'class'], aggfunc='sum', observed=False).unstack()

# Cambiar los nombres de las columnas del DataFrame pivotado a español
pivot_df.columns = ['Primera Clase', 'Segunda Clase', 'Tercera Clase']

# Crear un gráfico de barras apiladas
pivot_df.plot(kind='bar', stacked=True)

# Agregar títulos y etiquetas
plt.title('Supervivencia vs Clase, agrupadas por Puerto de Embarque')
plt.xlabel('Puerto de Embarque, Clase')
plt.ylabel('Supervivencia')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### i) pairplot para mostrar gráficos de dispersión y histogramas de las variables 'Age', 'Fare' y 'Pclass' del Titanic, diferenciando entre los pasajeros que sobrevivieron y los que no.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar los datos para los pasajeros que sobrevivieron y los que no
sobrevivieron = titanic_df[titanic_df['survived'] == 1]
no_sobrevivieron = titanic_df[titanic_df['survived'] == 0]

# Crear el pairplot
sns.pairplot(titanic_df, vars=['age', 'fare', 'pclass'], hue='survived', palette='husl')

# Añadir título
plt.suptitle('Pairplot de Age, Fare y Pclass según supervivencia')

# Mostrar el gráfico
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Otra forma de hacer el gráfico

# %%
# Importar seaborn
import seaborn as sns

# Crear un pairplot de 'age', 'fare' y 'pclass', coloreado por 'survived'
sns.pairplot(df[['age', 'fare', 'pclass', 'survived']].dropna(), hue='survived')

# Mostrar el gráfico
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
